# %%
import time

# %%
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
import dataset
import tree as miptree
from sklearn import tree

# %%
timelimit = 600
datasets = ['balance-scale', 'breast-cancer', 'car-evaluation', 'hayes-roth', 'house-votes-84', 
            'soybean-small', 'spect', 'tic-tac-toe', 'monks-1', 'monks-2', 'monks-3']
alpha = [0, 0.01, 0.1]
depth = [2, 3, 4, 5]
seeds = [31, 42, 53]

# %%
datasets
# Out:
# ['balance-scale',
#  'breast-cancer',
#  'car-evaluation',
#  'hayes-roth',
#  'house-votes-84',
#  'soybean-small',
#  'spect',
#  'tic-tac-toe',
#  'monks-1',
#  'monks-2',
#  'monks-3']

# %%
train_ratio = 0.5
val_ratio = 0.25
test_ratio = 0.25

# %%
# create table
res_sk = pd.DataFrame(columns=['instance', 'depth', 'seed', 'train_acc', 'val_acc', 'test_acc', 'train_time'])
res_oct = pd.DataFrame(columns=['instance', 'depth', 'alpha', 'seed', 'train_acc', 'val_acc', 'test_acc', 'train_time'])
res_mfoct = pd.DataFrame(columns=['instance', 'depth', 'alpha', 'seed', 'train_acc', 'val_acc', 'test_acc', 'train_time'])
res_boct = pd.DataFrame(columns=['instance', 'depth', 'seed', 'train_acc', 'val_acc', 'test_acc', 'train_time'])

# %%
for s in seeds:
    for d in depth:
        for data in datasets:
            x, y = dataset.loadData(data)
            x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=1-train_ratio, random_state=s)
            x_val, x_test, y_val, y_test = train_test_split(x_test, y_test, 
                                                            test_size=test_ratio/(test_ratio+val_ratio), random_state=s)
            clf = tree.DecisionTreeClassifier(max_depth=2)
            tick = time.time()
            clf.fit(x_train, y_train)
            tock = time.time()
            train_time = tock - tick
            train_acc = accuracy_score(y_train, clf.predict(x_train))
            val_acc = accuracy_score(y_val, clf.predict(x_val))
            test_acc = accuracy_score(y_test, clf.predict(x_test))
            row = {'instance':data, 'depth':d, 'seed':s, 'train_acc':train_acc, 
                   'val_acc':val_acc, 'test_acc':test_acc, 'train_time':train_time}
            res_sk = res_sk.append(row, ignore_index=True)
            res_sk.to_csv('./res/sk.csv', index=False)

# %%
for s in seeds:
    for d in depth:
        for data in datasets:
            # load data
            x, y = dataset.loadData(data)
            # onehot encoding
            x_enc = dataset.oneHot(x)
            # data splition
            x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=1-train_ratio, random_state=s)
            x_val, x_test, y_val, y_test = train_test_split(x_test, y_test, 
                                                            test_size=test_ratio/(test_ratio+val_ratio), random_state=s)
            x_train_enc, x_test_enc, y_train, y_test = train_test_split(x_enc, y, test_size=1-train_ratio, random_state=s)
            x_val_enc, x_test_enc, y_val, y_test = train_test_split(x_test_enc, y_test, 
                                                                    test_size=test_ratio/(test_ratio+val_ratio), random_state=s)
            
            for a in alpha:
                # oct
                octree = miptree.optimalDecisionTreeClassifier(max_depth=d, min_samples_split=0, alpha=a,
                                                               timelimit=timelimit, output=False)
                tick = time.time()
                octree.fit(x_train, y_train)
                tock = time.time()
                train_time = tock - tick
                train_acc = accuracy_score(y_train, octree.predict(x_train))
                val_acc = accuracy_score(y_val, octree.predict(x_val))
                test_acc = accuracy_score(y_test, octree.predict(x_test))
                row = {'instance':data, 'depth':d, 'alpha':a, 'seed':s, 'train_acc':train_acc, 'val_acc':val_acc,
                       'test_acc':test_acc, 'train_time':train_time}
                res_oct = res_oct.append(row, ignore_index=True)
                res_oct.to_csv('./res/oct.csv', index=False)
                print(data, 'oct-d{}-a{}'.format(d,a), 'train acc:', train_acc, 'train acc:', val_acc)
                #print(row)
                
                # mfoct
                mfoct = miptree.maxFlowOptimalDecisionTreeClassifier(max_depth=d, alpha=a,
                                                                     timelimit=timelimit, output=False)
                tick = time.time()
                mfoct.fit(x_train_enc, y_train)
                tock = time.time()
                train_time = tock - tick
                train_acc = accuracy_score(y_train, mfoct.predict(x_train_enc))
                val_acc = accuracy_score(y_val, mfoct.predict(x_val_enc))
                test_acc = accuracy_score(y_test, mfoct.predict(x_test_enc))
                row = {'instance':data, 'depth':d, 'alpha':a, 'seed':s, 'train_acc':train_acc, 'val_acc':val_acc,
                       'test_acc':test_acc, 'train_time':train_time}
                res_mfoct = res_mfoct.append(row, ignore_index=True)
                res_mfoct.to_csv('./res/mfoct.csv', index=False)
                print(data, 'mfoct-d{}-a{}'.format(d,a), 'train acc:', train_acc, 'train acc:', val_acc)
                #print(row)
            
            # boct
            boct = miptree.binOptimalDecisionTreeClassifier(max_depth=d, min_samples_split=0,
                                                            timelimit=timelimit, output=False)
            tick = time.time()
            boct.fit(x_train, y_train)
            tock = time.time()
            train_time = tock - tick
            train_acc = accuracy_score(y_train, boct.predict(x_train))
            val_acc = accuracy_score(y_val, boct.predict(x_val))
            test_acc = accuracy_score(y_test, boct.predict(x_test))
            row = {'instance':data, 'depth':d, 'seed':s, 'train_acc':train_acc, 'val_acc':val_acc,
                   'test_acc':test_acc, 'train_time':train_time}
            res_boct = res_boct.append(row, ignore_index=True)
            res_boct.to_csv('./res/boct.csv', index=False)
            print(data, 'boct-d{}'.format(d), 'train acc:', train_acc, 'train acc:', val_acc)
            #print(row)
# Out:
# Training data include 312 instances, 4 features.
# Academic license - for non-commercial use only - expires 2021-06-13
# Using license file C:\Users\Apocrypse\gurobi.lic
# Changed value of parameter timelimit to 600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# balance-scale oct-d2-a0 train acc: 0.7211538461538461 train acc: 0.6730769230769231
# balance-scale mfoct-d2-a0 train acc: 0.6730769230769231 train acc: 0.7307692307692307
# Training data include 312 instances, 4 features.
# Changed value of parameter timelimit to 600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# balance-scale oct-d2-a0.01 train acc: 0.7211538461538461 train acc: 0.6730769230769231
# balance-scale mfoct-d2-a0.01 train acc: 0.6730769230769231 train acc: 0.7307692307692307
# Training data include 312 instances, 4 features.
# Changed value of parameter timelimit to 600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# balance-scale oct-d2-a0.1 train acc: 0.7019230769230769 train acc: 0.6666666666666666
# balance-scale mfoct-d2-a0.1 train acc: 0.6634615384615384 train acc: 0.7435897435897436
# Training data include 312 instances, 4 features.
# Changed value of parameter timelimit to 600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# balance-scale boct-d2 train acc: 0.6794871794871795 train acc: 0.7051282051282052
# Training data include 138 instances, 9 features.
# Changed value of parameter timelimit to 600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# breast-cancer oct-d2-a0 train acc: 0.7608695652173914 train acc: 0.7391304347826086
# breast-cancer mfoct-d2-a0 train acc: 0.7898550724637681 train acc: 0.7681159420289855
# Training data include 138 instances, 9 features.
# Changed value of parameter timelimit to 600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# breast-cancer oct-d2-a0.01 train acc: 0.7608695652173914 train acc: 0.8115942028985508
# breast-cancer mfoct-d2-a0.01 train acc: 0.7898550724637681 train acc: 0.7681159420289855
# Training data include 138 instances, 9 features.
# Changed value of parameter timelimit to 600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# breast-cancer oct-d2-a0.1 train acc: 0.7463768115942029 train acc: 0.7536231884057971
# breast-cancer mfoct-d2-a0.1 train acc: 0.7463768115942029 train acc: 0.7536231884057971
# Training data include 138 instances, 9 features.
# Changed value of parameter timelimit to 600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# breast-cancer boct-d2 train acc: 0.7536231884057971 train acc: 0.7391304347826086
# Training data include 864 instances, 6 features.
# Changed value of parameter timelimit to 600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# car-evaluation oct-d2-a0 train acc: 0.7743055555555556 train acc: 0.7569444444444444
# car-evaluation mfoct-d2-a0 train acc: 0.7743055555555556 train acc: 0.7569444444444444
# Training data include 864 instances, 6 features.
# Changed value of parameter timelimit to 600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# car-evaluation oct-d2-a0.01 train acc: 0.7743055555555556 train acc: 0.7569444444444444
# car-evaluation mfoct-d2-a0.01 train acc: 0.7743055555555556 train acc: 0.7569444444444444
# Training data include 864 instances, 6 features.
# Changed value of parameter timelimit to 600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# car-evaluation oct-d2-a0.1 train acc: 0.6932870370370371 train acc: 0.7337962962962963
# car-evaluation mfoct-d2-a0.1 train acc: 0.6932870370370371 train acc: 0.7337962962962963
# Training data include 864 instances, 6 features.
# Changed value of parameter timelimit to 600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# car-evaluation boct-d2 train acc: 0.7743055555555556 train acc: 0.7569444444444444
# Training data include 80 instances, 9 features.
# Changed value of parameter timelimit to 600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# hayes-roth oct-d2-a0 train acc: 0.6375 train acc: 0.625
# hayes-roth mfoct-d2-a0 train acc: 0.6375 train acc: 0.625
# Training data include 80 instances, 9 features.
# Changed value of parameter timelimit to 600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# hayes-roth oct-d2-a0.01 train acc: 0.6375 train acc: 0.625
# hayes-roth mfoct-d2-a0.01 train acc: 0.6375 train acc: 0.625
# Training data include 80 instances, 9 features.
# Changed value of parameter timelimit to 600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# hayes-roth oct-d2-a0.1 train acc: 0.6125 train acc: 0.5
# hayes-roth mfoct-d2-a0.1 train acc: 0.6125 train acc: 0.5
# Training data include 80 instances, 9 features.
# Changed value of parameter timelimit to 600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# hayes-roth boct-d2 train acc: 0.6375 train acc: 0.625
# Training data include 116 instances, 16 features.
# Changed value of parameter timelimit to 600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# house-votes-84 oct-d2-a0 train acc: 0.9913793103448276 train acc: 0.9655172413793104
# house-votes-84 mfoct-d2-a0 train acc: 0.9913793103448276 train acc: 0.9655172413793104
# Training data include 116 instances, 16 features.
# Changed value of parameter timelimit to 600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# house-votes-84 oct-d2-a0.01 train acc: 0.9913793103448276 train acc: 0.9655172413793104
# house-votes-84 mfoct-d2-a0.01 train acc: 0.9913793103448276 train acc: 0.9655172413793104
# Training data include 116 instances, 16 features.
# Changed value of parameter timelimit to 600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# house-votes-84 oct-d2-a0.1 train acc: 0.9913793103448276 train acc: 0.9655172413793104
# house-votes-84 mfoct-d2-a0.1 train acc: 0.9913793103448276 train acc: 0.9655172413793104
# Training data include 116 instances, 16 features.
# Changed value of parameter timelimit to 600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# house-votes-84 boct-d2 train acc: 0.9913793103448276 train acc: 0.9310344827586207
# Training data include 23 instances, 50 features.
# Changed value of parameter timelimit to 600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# soybean-small oct-d2-a0 train acc: 0.30434782608695654 train acc: 0.5833333333333334
# soybean-small mfoct-d2-a0 train acc: 1.0 train acc: 0.6666666666666666
# Training data include 23 instances, 50 features.
# Changed value of parameter timelimit to 600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# soybean-small oct-d2-a0.01 train acc: 1.0 train acc: 1.0
# soybean-small mfoct-d2-a0.01 train acc: 1.0 train acc: 0.6666666666666666
# Training data include 23 instances, 50 features.
# Changed value of parameter timelimit to 600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# soybean-small oct-d2-a0.1 train acc: 0.9565217391304348 train acc: 0.6666666666666666
# soybean-small mfoct-d2-a0.1 train acc: 0.9565217391304348 train acc: 0.6666666666666666
# Training data include 23 instances, 36 features.
# Changed value of parameter timelimit to 600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# soybean-small boct-d2 train acc: 1.0 train acc: 1.0
# Training data include 133 instances, 22 features.
# Changed value of parameter timelimit to 600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# spect oct-d2-a0 train acc: 0.849624060150376 train acc: 0.7910447761194029
# spect mfoct-d2-a0 train acc: 0.849624060150376 train acc: 0.7910447761194029
# Training data include 133 instances, 22 features.
# Changed value of parameter timelimit to 600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# spect oct-d2-a0.01 train acc: 0.849624060150376 train acc: 0.7910447761194029
# spect mfoct-d2-a0.01 train acc: 0.849624060150376 train acc: 0.7910447761194029
# Training data include 133 instances, 22 features.
# Changed value of parameter timelimit to 600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# spect oct-d2-a0.1 train acc: 0.849624060150376 train acc: 0.7910447761194029
# spect mfoct-d2-a0.1 train acc: 0.849624060150376 train acc: 0.7910447761194029
# Training data include 133 instances, 22 features.
# Changed value of parameter timelimit to 600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
